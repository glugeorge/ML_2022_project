# %%
# !pip install -U tensorflow
# Out:
# ...
#   Using cached tensorflow-2.10.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (578.1 MB)
# ...
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# ...
#   Using cached absl_py-1.3.0-py3-none-any.whl (124 kB)
# ...
#   Using cached tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# ...
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# ...
#   Using cached tensorflow_io_gcs_filesystem-0.27.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
# ...
#   Using cached tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
# ...
#   Using cached keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
# ...
#   Using cached libclang-14.0.6-py2.py3-none-manylinux2010_x86_64.whl (14.1 MB)
# ...
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# ...
#   Using cached protobuf-3.19.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# ...

# %%
import intake
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import keras
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.layers import *
from keras.optimizers import SGD, Adam
from keras.models import Sequential
from keras.utils import to_categorical
# Out:
# 2022-10-19 20:25:32.436220: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-19 20:25:32.607538: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-10-19 20:25:32.607591: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-10-19 20:25:32.644401: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
ds_surface_ref = xr.open_dataset('racmo_wessem_mean-d1.nc')

# %%
ds_ref = ds_surface_ref.assign_coords(time=[0])

# %%
precip_ref = ds_ref.precipitation

# %%
ds_forcing = xr.open_dataset('timeseries_edc-wdc_temp.nc',decode_times=False)

# %%
ds_forcing.delta_T.plot()

# %% [markdown]
# Load in PISM results

# %%
cat = intake.open_catalog('https://raw.githubusercontent.com/ldeo-glaciology/pangeo-pismpaleo/main/paleopism.yaml')

# %%
from dask.distributed import Client

client = Client("tcp://127.0.0.1:45629")
client
# Out:
# <Client: 'tcp://127.0.0.1:45629' processes=4 threads=4, memory=14.65 GiB>

# %%
cat
# Out:
# paleopism:
#   args:
#     path: https://raw.githubusercontent.com/ldeo-glaciology/pangeo-pismpaleo/main/paleopism.yaml
#   description: ''
#   driver: intake.catalog.local.YAMLFileCatalog
#   metadata: {}

# %%
present  = cat["present"].to_dask()
snapshots = cat["snapshots1ka"].to_dask()

# %%
snapshots
# Out:
# <xarray.Dataset>
# Dimensions:     (time: 125, y: 381, x: 381, par_esia: 4, par_ppq: 4,
#                  par_prec: 4, par_visc: 4)
# Coordinates:
#   * par_esia    (par_esia) float64 1.0 2.0 4.0 7.0
#   * par_ppq     (par_ppq) float64 0.25 0.5 0.75 1.0
#   * par_prec    (par_prec) float64 0.02 0.05 0.07 0.1
#   * par_visc    (par_visc) float64 1e+20 5e+20 2.5e+21 1e+22
#   * time        (time) float64 -1.24e+05 -1.23e+05 -1.22e+05 ... -1e+03 0.0
#   * x           (x) float64 -3.04e+06 -3.024e+06 ... 3.024e+06 3.04e+06
#   * y           (y) float64 -3.04e+06 -3.024e+06 ... 3.024e+06 3.04e+06
# Data variables:
#     bmelt       (time, y, x, par_esia, par_ppq, par_prec, par_visc) float32 dask.array<chunksize=(25, 381, 381, 1, 4, 4, 4), meta=np.ndarray>
#     dbdt        (time, y, x, par_esia, par_ppq, par_prec, par_visc) float32 dask.array<chunksize=(25, 381, 381, 1, 4, 4, 4), meta=np.ndarray>
# ...

# %%
ref_height = snapshots.usurf.isel(time=124)

# %% [markdown]
# Interpolating forcing

# %%
ds_forcing_interp = ds_forcing.interp(time=snapshots.time)
ds_forcing_interp.delta_T.plot()

# %% [markdown]
# Test out applying anomaly (without including lapse rate + elevation adjustment) to each grid point

# %%
precip_evol = precip_ref

# %%
precip_evol.plot()

# %%
precip_evol = precip_ref*(1 + snapshots.par_prec*ds_forcing_interp.delta_T.isel(time=0))-0.554*(snapshots.usurf.isel(time=0)-ref_height)/1000
precip_evol = precip_temp.assign_coords(time=[snapshots.time[0]])

# %%
for i in range(1,len(snapshots.time)):
    precip_temp = precip_ref*(1 + snapshots.par_prec*ds_forcing_interp.delta_T.isel(time=i))-0.554*(snapshots.usurf.isel(time=i)-ref_height)/1000
    precip_temp = precip_temp.assign_coords(time=[snapshots.time[i]])
    precip_evol = xr.concat([precip_evol,precip_temp],dim='time')

# %%
precip_evol.isel(par_esia=3,par_ppq = 2, par_prec= 1,par_visc = 2,time = 0).plot()

# %%
precip_evol
# Out:
# <xarray.DataArray (time: 125, y: 381, x: 381, par_prec: 4, par_esia: 4,
#                    par_ppq: 4, par_visc: 4)>
# dask.array<concatenate, shape=(125, 381, 381, 4, 4, 4, 4), dtype=float64, chunksize=(1, 381, 381, 4, 1, 4, 4), chunktype=numpy.ndarray>
# Coordinates:
#     lat       (y, x) float64 -51.85 -51.94 -52.04 ... -52.04 -51.94 -51.85
#     lon       (y, x) float64 -135.0 -135.2 -135.3 -135.5 ... 44.7 44.85 45.0
#   * time      (time) float64 -1.24e+05 -1.23e+05 -1.22e+05 ... -2e+03 -1e+03 0.0
#   * x         (x) float64 -3.04e+06 -3.024e+06 -3.008e+06 ... 3.024e+06 3.04e+06
#   * y         (y) float64 -3.04e+06 -3.024e+06 -3.008e+06 ... 3.024e+06 3.04e+06
#   * par_prec  (par_prec) float64 0.02 0.05 0.07 0.1
#   * par_esia  (par_esia) float64 1.0 2.0 4.0 7.0
#   * par_ppq   (par_ppq) float64 0.25 0.5 0.75 1.0
#   * par_visc  (par_visc) float64 1e+20 5e+20 2.5e+21 1e+22

# %% [markdown]
# Trying out plotting mean surface height for 1 ensemble member over time

# %%
snapshots.usurf.isel(par_esia=3,par_ppq = 2, par_prec= 1,par_visc = 2).mean(dim='time').plot(size = 10)

# %% [markdown]
# Now let's try to format this data for a very simple NN that takes into account position, bed thickness, surface height?

# %% [markdown]
# Make everything into pandas dataframe. First try doing X (predictors) with surface height and bed elevation.

# %%
import pandas as pd
import dask.dataframe as dd

# %%
! pip install xbatcher
import xbatcher

# %%
grounded_ice = snapshots.where('mask'==2)

# %%
test = grounded_ice.drop_vars(["bmelt","dbdt","thk","score","index"])

# %%
test
# Out:
# <xarray.Dataset>
# Dimensions:     (time: 125, y: 381, x: 381, par_esia: 4, par_ppq: 4,
#                  par_prec: 4, par_visc: 4)
# Coordinates:
#   * par_esia    (par_esia) float64 1.0 2.0 4.0 7.0
#   * par_ppq     (par_ppq) float64 0.25 0.5 0.75 1.0
#   * par_prec    (par_prec) float64 0.02 0.05 0.07 0.1
#   * par_visc    (par_visc) float64 1e+20 5e+20 2.5e+21 1e+22
#   * time        (time) float64 -1.24e+05 -1.23e+05 -1.22e+05 ... -1e+03 0.0
#   * x           (x) float64 -3.04e+06 -3.024e+06 ... 3.024e+06 3.04e+06
#   * y           (y) float64 -3.04e+06 -3.024e+06 ... 3.024e+06 3.04e+06
# Data variables:
#     mask        (time, y, x, par_esia, par_ppq, par_prec, par_visc) float64 dask.array<chunksize=(125, 381, 381, 4, 4, 4, 4), meta=np.ndarray>
#     topg        (time, y, x, par_esia, par_ppq, par_prec, par_visc) float32 dask.array<chunksize=(125, 381, 381, 4, 4, 4, 4), meta=np.ndarray>
# ...

# %%
smaller_test = test.isel(par_esia=[1,2],par_ppq = [2,3], par_prec= [1,2],par_visc = [1,2])

# %%
smaller_test
# Out:
# <xarray.Dataset>
# Dimensions:     (time: 125, y: 381, x: 381, par_esia: 2, par_ppq: 2,
#                  par_prec: 2, par_visc: 2)
# Coordinates:
#   * par_esia    (par_esia) float64 4.0 7.0
#   * par_ppq     (par_ppq) float64 0.75 1.0
#   * par_prec    (par_prec) float64 0.05 0.07
#   * par_visc    (par_visc) float64 5e+20 2.5e+21
#   * time        (time) float64 -1.24e+05 -1.23e+05 -1.22e+05 ... -1e+03 0.0
#   * x           (x) float64 -3.04e+06 -3.024e+06 ... 3.024e+06 3.04e+06
#   * y           (y) float64 -3.04e+06 -3.024e+06 ... 3.024e+06 3.04e+06
# Data variables:
#     mask        (time, y, x, par_esia, par_ppq, par_prec, par_visc) float64 dask.array<chunksize=(125, 381, 381, 2, 2, 2, 2), meta=np.ndarray>
#     topg        (time, y, x, par_esia, par_ppq, par_prec, par_visc) float32 dask.array<chunksize=(125, 381, 381, 2, 2, 2, 2), meta=np.ndarray>
# ...
